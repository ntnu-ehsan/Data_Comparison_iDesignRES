# %% [markdown]
# # Introduction
#
# This notebook provides a systematic comparison of datasets collected by different teams throughout the **iDesignRES** project. Because multiple teams have independently gathered data on the same domain, discrepancies in values, units, sources, or methodologies may exist between datasets.
#
# The primary objectives of this analysis are:
#
# - **Identify discrepancies** between datasets contributed by different teams
# - **Assess data quality** by evaluating completeness, consistency, and source reliability
# - **Select the most accurate dataset** to use as the foundation for subsequent project phases
#
# Choosing the right data at this stage is critical, as downstream analyses, models, and design decisions will depend on its accuracy and reliability.
